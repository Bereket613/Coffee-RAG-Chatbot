# %% [markdown]
# <a href="https://colab.research.google.com/github/Bereket613/Coffee-RAG-Chatbot/blob/main/fine_tune_LLaMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import chromadb

# %%
# !python build_vector_db.py
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(
# 🚀 Creating Vector Database...
# Batches: 100% 19/19 [00:20<00:00,  1.10s/it]
# ✅ Vector database created successfully! You can now run the chatbot.
# 📁 Database saved in: vector_db

# %%
# !python app.py
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(
# ✅ Collection loaded with 602 chunks
# `torch_dtype` is deprecated! Use `dtype` instead!
# Device set to use cpu
# ✅ Coffee RAG Chatbot initialized successfully!
# /content/app.py:230: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot_interface = gr.Chatbot(
# Traceback (most recent call last):
#   File "/content/app.py", line 349, in <module>
#     demo = create_gradio_interface()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/app.py", line 272, in create_gradio_interface
#     examples = gr.Examples(
#                ^^^^^^^^^^^^
# TypeError: create_examples() got an unexpected keyword argument 'elem_classes'

# %%
# !python rag_chatbot.py
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(
# Using device: cpu
# 🚀 Initializing Ethiopian Coffee RAG Chatbot...
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Available collections: ['coffee_disease']
# ✅ Collection loaded with 602 chunks
# config.json: 100% 642/642 [00:00<00:00, 7.16MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# pytorch_model.bin: 100% 863M/863M [00:02<00:00, 427MB/s]
# model.safetensors:   0% 0.00/863M [00:00<?, ?B/s]
# generation_config.json: 100% 124/124 [00:00<00:00, 1.19MB/s]
#
# tokenizer_config.json: 100% 614/614 [00:00<00:00, 5.85MB/s]
#
# vocab.json: 1.04MB [00:00, 46.9MB/s]
#
# merges.txt: 456kB [00:00, 138MB/s]
# model.safetensors:   8% 67.0M/863M [00:01<00:12, 61.9MB/s]Device set to use cpu
# ✅ Coffee RAG Chatbot initialized successfully!
#
# ============================================================
# ☕ Ethiopian Coffee Disease Research Assistant
# ============================================================
# Ask me about Ethiopian coffee diseases, symptoms, treatments,
# prevention methods, or any related agricultural practices.
#
# Type 'exit', 'quit', or 'bye' to end the conversation
# ============================================================
#
# model.safetensors: 100% 863M/863M [00:08<00:00, 107MB/s]
# hello
# 🤖 Bot: Researching...ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# 🔍 Retrieved 3 relevant chunks
# 🤖 Generating answer...
# 🤖 Bot: I don't have enough specific information to answer that question based on my knowledge base.
#
# 🧑 You: What is the main cause of coffee leaf rust?
# 🤖 Bot: Researching...🔍 Retrieved 3 relevant chunks
# 🤖 Generating answer...
# 🤖 Bot: I don't have enough specific information to answer that question based on my knowledge base.
#
# 🧑 You:

# %%
# !mkdir -p data/chunks

# %%
# !mv *_chunks.txt data/chunks/

# %%
# !mv *.txt data/chunks/

# %%
# !find /content -maxdepth 1 -name "*_chunks.txt" -exec mv {} data/chunks/ \;

# %%
# !ls data/chunks
# Out:
#  1_chunks.txt
#  1.txt
# '20. Biniyam Yoseph (1)_chunks.txt'
# '20. Biniyam Yoseph (1).txt'
#  6_chunks.txt
#  6.txt
#  Coffee_Leaf_Plant_Disease_Identification_through_I_chunks.txt
#  Coffee_Leaf_Plant_Disease_Identification_through_I.txt
#  deep-learning-for-coffee-disease-classification-international-journal-of-computer-trends-and-technology-ijctt-mikias-legesse_chunks.txt
#  deep-learning-for-coffee-disease-classification-international-journal-of-computer-trends-and-technology-ijctt-mikias-legesse.txt
#  Detection_and_classification_of_coffee_leafdisease_chunks.txt
#  Detection_and_classification_of_coffee_leafdisease.txt
#  JETIR2110156_chunks.txt
#  JETIR2110156.txt
#  rd.20230404.13_chunks.txt
#  rd.20230404.13.txt
